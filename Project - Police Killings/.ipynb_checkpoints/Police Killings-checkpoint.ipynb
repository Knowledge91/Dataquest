# %% [markdown]
# ## 2: Introduction
# ---

# %%
import pandas as pd

police_killings = pd.read_csv('police_killings.csv', encoding='ISO-8859-1')
police_killings.head()
# Out:
#                  name age gender    raceethnicity     month  day  year  \
# 0  A'donte Washington  16   Male            Black  February   23  2015
# 1      Aaron Rutledge  27   Male            White     April    2  2015
# 2         Aaron Siler  26   Male            White     March   14  2015
# 3        Aaron Valdez  25   Male  Hispanic/Latino     March   11  2015
# 4        Adam Jovicic  29   Male            White     March   19  2015
#
#             streetaddress          city state    ...     share_hispanic  \
# 0            Clearview Ln     Millbrook    AL    ...                5.6
# 1  300 block Iris Park Dr     Pineville    LA    ...                0.5
# 2    22nd Ave and 56th St       Kenosha    WI    ...               16.8
# 3       3000 Seminole Ave    South Gate    CA    ...               98.8
# 4          364 Hiwood Ave  Munroe Falls    OH    ...                1.7
#
#    p_income  h_income  county_income  comp_income  county_bucket  nat_bucket  \
# ...

# %%
police_killings.columns
# Out:
# Index(['name', 'age', 'gender', 'raceethnicity', 'month', 'day', 'year',
#        'streetaddress', 'city', 'state', 'latitude', 'longitude', 'state_fp',
#        'county_fp', 'tract_ce', 'geo_id', 'county_id', 'namelsad',
#        'lawenforcementagency', 'cause', 'armed', 'pop', 'share_white',
#        'share_black', 'share_hispanic', 'p_income', 'h_income',
#        'county_income', 'comp_income', 'county_bucket', 'nat_bucket', 'pov',
#        'urate', 'college'],
#       dtype='object')

# %% [markdown]
# ## 3: Shootings By Race
# ---

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

# print(police_killings['raceethnicity'].value_counts())
# print(police_killings['raceethnicity'].value_counts().index)
xticks_offset = range(0, len(police_killings['raceethnicity'].value_counts()))

plt.bar(range(len(police_killings['raceethnicity'].value_counts())), police_killings['raceethnicity'].value_counts())
plt.xticks(xticks_offset , police_killings['raceethnicity'].value_counts().index, rotation=90 )
plt.show()

# %%
police_killings['raceethnicity'].value_counts() / police_killings['raceethnicity'].value_counts().sum()
# Out:
# White                     0.505353
# Black                     0.289079
# Hispanic/Latino           0.143469
# Unknown                   0.032120
# Asian/Pacific Islander    0.021413
# Native American           0.008565
# Name: raceethnicity, dtype: float64

# %% [markdown]
# ### Raceethnicity
#
# It looks like people identified as Black are far overrepresented in the shootings versus in the population of the US (28% vs 16%). You can see the breakdown of population by race [here](https://en.wikipedia.org/wiki/Race_and_ethnicity_in_the_United_States#Racial_makeup_of_the_U.S._population).
#
# People identified as Hispanic appear to be killed about as often as random chance would account for (14% of the people killed as Hispanic, versus 17% of the overall population).
#
# Whites are underrepresented among shooting victims vs their population percentage, as are Asians.

# %% [markdown]
# ## 4: Shootings By Regional Income
# ---

# %%
income = police_killings[police_killings['p_income'] != '-']
income['p_income'].astype(int).hist(bins=50)
plt.show()

income['p_income'].median()
# Out:
# 22348.0

# %% [markdown]
# ### Income breakdown
# According to the Census, median personal income in the US is 28,567, and our median is 22,348, which means that shootings tend to happen in less affluent areas. Our sample size is relatively small, though, so it's hard to make sweeping conclusions.

# %% [markdown]
# ## 5: Shootings By State
# ---

# %%
state_pop = pd.read_csv('state_population.csv')
state_pop.head()
# Out:
#    SUMLEV REGION DIVISION  STATE           NAME  POPESTIMATE2015  \
# 0      10      0        0      0  United States        321418820
# 1      40      3        6      1        Alabama          4858979
# 2      40      4        9      2         Alaska           738432
# 3      40      4        8      4        Arizona          6828065
# 4      40      3        7      5       Arkansas          2978204
#
#    POPEST18PLUS2015  PCNT_POPEST18PLUS
# 0         247773709               77.1
# 1           3755483               77.3
# 2            552166               74.8
# 3           5205215               76.2
# 4           2272904               76.3

# %%
counts = police_killings['state_fp'].value_counts()
states = pd.DataFrame({"STATE": counts.index, "shootings": counts})
states = state_pop.merge(states, on='STATE')

# %%
states['pop_millions'] = states['POPESTIMATE2015'] / 1000000
states['rate'] = states['shootings'] / states['pop_millions']
states.sort('rate', ascending=False)
# Out:
# /Users/Knowledge/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()
#     SUMLEV REGION DIVISION  STATE                  NAME  POPESTIMATE2015  \
# 35      40      3        7     40              Oklahoma          3911338
# 2       40      4        8      4               Arizona          6828065
# 27      40      2        4     31              Nebraska          1896190
# 11      40      4        9     15                Hawaii          1431603
# 1       40      4        9      2                Alaska           738432
# 12      40      4        8     16                 Idaho          1654930
# 31      40      4        8     35            New Mexico          2085109
# 18      40      3        7     22             Louisiana          4670724
# 5       40      4        8      8              Colorado          5456574
# ...

# %% [markdown]
# ### Shootings per million
# Oklahoma seems to be the Wild-West of America, followed with some distance by Nebraska and Arizona.
#
# The safest state (from the point of police killings) is Connecticut, followed by Pensylvania and Iowa.
#
# In general it seems that states in the midwest and south seem to have the highest police killing rates, whereas those in the northeast seem to have the lowest.

# %% [markdown]
# ## 6: State By State Differences
# ---

# %%
pk = police_killings[
    (police_killings["share_white"] != "-") & 
    (police_killings["share_black"] != "-") & 
    (police_killings["share_hispanic"] != "-")
]


pk[['share_white', 'share_black', 'share_hispanic']] = pk[['share_white', 'share_black', 'share_hispanic']].astype('float')

lowest_states = ["CT", "PA", "IA", "NY", "MA", "NH", "ME", "IL", "OH", "WI"]
highest_states = ["OK", "AZ", "NE", "HI", "AK", "ID", "NM", "LA", "CO", "DE"]

ls = pk[pk["state"].isin(lowest_states)]
hs = pk[pk["state"].isin(highest_states)]

columns = ['pop', 'county_income', 'share_white', 'share_black', 'share_hispanic']
# Out:
# pop                4201.660714
# county_income     54830.839286
# share_white          60.616071
# share_black          21.257143
# share_hispanic       12.948214
# dtype: float64
# pop                4315.750000
# county_income     48706.967391
# share_white          55.652174
# share_black          11.532609
# share_hispanic       20.693478
# dtype: float64
# /Users/Knowledge/anaconda/lib/python3.5/site-packages/pandas/core/frame.py:2378: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %% [markdown]
# ### 10 Lowest shooting states

# %%
print(ls[columns].mean())
# Out:
# pop                4201.660714
# county_income     54830.839286
# share_white          60.616071
# share_black          21.257143
# share_hispanic       12.948214
# dtype: float64

# %% [markdown]
# ### 10 Highest shooting states

# %%
print(hs[columns].mean())
# Out:
# pop                4315.750000
# county_income     48706.967391
# share_white          55.652174
# share_black          11.532609
# share_hispanic       20.693478
# dtype: float64

# %% [markdown]
# ### State by state rates
# It looks like the states with low rates of shootings tend to have a higher proportion of blacks in the population, and a lower proportion of hispanics in the census regions where the shootings occur. It looks like the income of the counties where the shootings occur is higher.
# States with high rates of shootings tend to have high hispanic population shares in the counties where shootings occur.
